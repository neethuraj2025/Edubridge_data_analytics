# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv('housing.csv')
d
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
d.shape
# Out:
# (34857, 21)

# %%
d.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
d.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
d['BuildingArea'].unique()
# Out:
# array([         nan, 7.900000e+01, 1.500000e+02, 1.420000e+02,
#        2.200000e+02, 2.100000e+02, 8.200000e+01, 1.470000e+02,
#        1.070000e+02, 7.500000e+01, 8.000000e+01, 1.900000e+02,
#        9.400000e+01, 9.700000e+01, 1.290000e+02, 1.100000e+02,
#        1.050000e+02, 7.300000e+01, 1.350000e+02, 1.670000e+02,
#        2.700000e+01, 6.000000e+01, 8.500000e+01, 1.740000e+02,
#        5.000000e+01, 1.280000e+02, 1.800000e+01, 1.240000e+02,
#        9.100000e+01, 8.100000e+01, 2.250000e+02, 1.450000e+02,
#        1.140000e+02, 8.400000e+01, 1.340000e+02, 1.160000e+02,
#        8.600000e+01, 1.270000e+02, 1.860000e+02, 9.000000e+01,
#        1.330000e+02, 1.300000e+02, 1.130000e+02, 1.000000e+02,
#        3.090000e+02, 1.920000e+02, 1.260000e+02, 1.010000e+02,
#        1.020000e+02, 7.600000e+01, 1.460000e+02, 1.980000e+02,
#        1.800000e+02, 1.250000e+02, 1.590000e+02, 1.220000e+02,
#        8.800000e+01, 1.810000e+02, 1.170000e+02, 9.800000e+01,
# ...

# %%
d.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
d.drop(['Lattitude','Longtitude'],axis=1,inplace=True)

# %%
d.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
d['Price']=d['Price'].fillna(d['Price'].mean())

# %%
d
# Out:
#            Suburb             Address  Rooms Type         Price Method  \
# 0      Abbotsford       68 Studley St      2    h  1.050173e+06     SS
# 1      Abbotsford        85 Turner St      2    h  1.480000e+06      S
# 2      Abbotsford     25 Bloomburg St      2    h  1.035000e+06      S
# 3      Abbotsford  18/659 Victoria St      3    u  1.050173e+06     VB
# 4      Abbotsford        5 Charles St      3    h  1.465000e+06     SP
# ...           ...                 ...    ...  ...           ...    ...
# 34852  Yarraville         13 Burns St      4    h  1.480000e+06     PI
# 34853  Yarraville       29A Murray St      2    h  8.880000e+05     SP
# 34854  Yarraville      147A Severn St      2    t  7.050000e+05      S
# 34855  Yarraville    12/37 Stephen St      3    h  1.140000e+06     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1.020000e+06     PI
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
d.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
d.drop(['Distance','Postcode','CouncilArea','Propertycount','Address','BuildingArea'],axis=1,inplace=True)

# %%
d
# Out:
#            Suburb  Rooms Type         Price Method        SellerG        Date  \
# 0      Abbotsford      2    h  1.050173e+06     SS         Jellis   3/09/2016
# 1      Abbotsford      2    h  1.480000e+06      S         Biggin   3/12/2016
# 2      Abbotsford      2    h  1.035000e+06      S         Biggin   4/02/2016
# 3      Abbotsford      3    u  1.050173e+06     VB         Rounds   4/02/2016
# 4      Abbotsford      3    h  1.465000e+06     SP         Biggin   4/03/2017
# ...           ...    ...  ...           ...    ...            ...         ...
# 34852  Yarraville      4    h  1.480000e+06     PI            Jas  24/02/2018
# 34853  Yarraville      2    h  8.880000e+05     SP        Sweeney  24/02/2018
# 34854  Yarraville      2    t  7.050000e+05      S            Jas  24/02/2018
# 34855  Yarraville      3    h  1.140000e+06     SP  hockingstuart  24/02/2018
# 34856  Yarraville      2    h  1.020000e+06     PI             RW  24/02/2018
#
# ...

# %%
d.isnull().sum()
# Out:
# Suburb            0
# Rooms             0
# Type              0
# Price             0
# Method            0
# SellerG           0
# Date              0
# Bedroom2       8217
# Bathroom       8226
# Car            8728
# Landsize      11810
# YearBuilt     19306
# Regionname        3
# dtype: int64

# %%
d['Car'].unique()
# Out:
# array([ 1.,  0.,  2., nan,  6.,  5.,  4.,  3.,  8.,  7., 11., 26.,  9.,
#        10., 18., 12.])

# %%
d.isnull().sum()
# Out:
# Suburb            0
# Rooms             0
# Type              0
# Price             0
# Method            0
# SellerG           0
# Date              0
# Bedroom2       8217
# Bathroom       8226
# Car            8728
# Landsize      11810
# YearBuilt     19306
# Regionname        3
# dtype: int64

# %%
d['Landsize']=d['Landsize'].fillna(d['Landsize'].mean())

# %%
d['YearBuilt']=d['YearBuilt'].fillna(d['YearBuilt'].median())

# %%
d.isnull().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Bedroom2      8217
# Bathroom      8226
# Car           8728
# Landsize         0
# YearBuilt        0
# Regionname       3
# dtype: int64

# %%
d.dropna(axis=0,inplace=True)

# %%
d.isnull().sum()
# Out:
# Suburb        0
# Rooms         0
# Type          0
# Price         0
# Method        0
# SellerG       0
# Date          0
# Bedroom2      0
# Bathroom      0
# Car           0
# Landsize      0
# YearBuilt     0
# Regionname    0
# dtype: int64

# %%
d['YearBuilt'].unique()
# Out:
# array([1970., 1900., 2014., 2006., 1910., 2009., 1860., 1890., 1925.,
#        2005., 2010., 1880., 1985., 2013., 2012., 1920., 1950., 1998.,
#        1930., 2016., 1965., 1960., 1980., 2011., 2015., 1975., 1993.,
#        2003., 1995., 1996., 2000., 1990., 1915., 2004., 2008., 1916.,
#        1962., 1955., 1988., 1953., 1997., 2007., 1967., 1964., 1889.,
#        1888., 1934., 1966., 1935., 1969., 1940., 1938., 1887., 1904.,
#        1972., 1978., 1939., 1945., 1927., 1948., 1947., 1968., 1958.,
#        2017., 1999., 1992., 1961., 1928., 1977., 1919., 1976., 2001.,
#        1926., 1981., 1986., 1943., 1974., 1956., 1936., 1957., 1987.,
#        2002., 1952., 1994., 1949., 1905., 1912., 1924., 1885., 1923.,
#        1918., 1991., 1942., 1973., 2018., 1982., 2106., 1971., 1963.,
#        1931., 1897., 1906., 1883., 1989., 1983., 1937., 1903., 1913.,
#        1830., 1895., 1908., 1917., 1902., 1854., 1850., 1898., 1941.,
# ...

# %%
d['Landsize'].unique()
# Out:
# array([ 126.,  202.,  156., ..., 2148., 1109., 1163.])

# %%
d.shape
# Out:
# (26129, 13)

# %%
d
# Out:
#            Suburb  Rooms Type         Price Method  SellerG        Date  \
# 0      Abbotsford      2    h  1.050173e+06     SS   Jellis   3/09/2016
# 1      Abbotsford      2    h  1.480000e+06      S   Biggin   3/12/2016
# 2      Abbotsford      2    h  1.035000e+06      S   Biggin   4/02/2016
# 3      Abbotsford      3    u  1.050173e+06     VB   Rounds   4/02/2016
# 4      Abbotsford      3    h  1.465000e+06     SP   Biggin   4/03/2017
# ...           ...    ...  ...           ...    ...      ...         ...
# 34850     Wollert      3    h  1.050173e+06     SP       LJ  24/02/2018
# 34852  Yarraville      4    h  1.480000e+06     PI      Jas  24/02/2018
# 34853  Yarraville      2    h  8.880000e+05     SP  Sweeney  24/02/2018
# 34854  Yarraville      2    t  7.050000e+05      S      Jas  24/02/2018
# 34856  Yarraville      2    h  1.020000e+06     PI       RW  24/02/2018
#
#        Bedroom2  Bathroom  Car  Landsize  YearBuilt             Regionname
# ...

# %%
d.isnull().sum()
# Out:
# Suburb        0
# Rooms         0
# Type          0
# Price         0
# Method        0
# SellerG       0
# Date          0
# Bedroom2      0
# Bathroom      0
# Car           0
# Landsize      0
# YearBuilt     0
# Regionname    0
# dtype: int64

# %% [markdown]
# ## Printing first 5 rows

# %%
d.head()
# Out:
#        Suburb  Rooms Type         Price Method SellerG       Date  Bedroom2  \
# 0  Abbotsford      2    h  1.050173e+06     SS  Jellis  3/09/2016       2.0
# 1  Abbotsford      2    h  1.480000e+06      S  Biggin  3/12/2016       2.0
# 2  Abbotsford      2    h  1.035000e+06      S  Biggin  4/02/2016       2.0
# 3  Abbotsford      3    u  1.050173e+06     VB  Rounds  4/02/2016       3.0
# 4  Abbotsford      3    h  1.465000e+06     SP  Biggin  4/03/2017       3.0
#
#    Bathroom  Car  Landsize  YearBuilt             Regionname
# 0       1.0  1.0     126.0     1970.0  Northern Metropolitan
# 1       1.0  1.0     202.0     1970.0  Northern Metropolitan
# 2       1.0  0.0     156.0     1900.0  Northern Metropolitan
# 3       2.0  1.0       0.0     1970.0  Northern Metropolitan
# 4       2.0  0.0     134.0     1900.0  Northern Metropolitan

# %% [markdown]
# ## Printing last 5 rows

# %%
d.tail()
# Out:
#            Suburb  Rooms Type         Price Method  SellerG        Date  \
# 34850     Wollert      3    h  1.050173e+06     SP       LJ  24/02/2018
# 34852  Yarraville      4    h  1.480000e+06     PI      Jas  24/02/2018
# 34853  Yarraville      2    h  8.880000e+05     SP  Sweeney  24/02/2018
# 34854  Yarraville      2    t  7.050000e+05      S      Jas  24/02/2018
# 34856  Yarraville      2    h  1.020000e+06     PI       RW  24/02/2018
#
#        Bedroom2  Bathroom  Car  Landsize  YearBuilt             Regionname
# 34850       3.0       2.0  2.0     268.0     2016.0  Northern Metropolitan
# 34852       4.0       1.0  3.0     593.0     1970.0   Western Metropolitan
# 34853       2.0       2.0  1.0      98.0     2018.0   Western Metropolitan
# 34854       2.0       1.0  2.0     220.0     2000.0   Western Metropolitan
# 34856       2.0       1.0  0.0     250.0     1930.0   Western Metropolitan

# %% [markdown]
# ## Printing 10 sample/random rows

# %%
d.sample(10)
# Out:
#                 Suburb  Rooms Type         Price Method   SellerG        Date  \
# 12887          Glenroy      5    t  6.450000e+05      S     Barry  20/05/2017
# 15444     Balwyn North      4    h  2.050000e+06      S    Jellis  17/06/2017
# 21652         Armadale      2    h  1.460000e+06      S    Jellis  19/08/2017
# 5101           Hampton      2    u  7.380000e+05      S    Buxton  26/07/2016
# 34523     Moonee Ponds      3    h  1.050173e+06     SN     Barry  24/02/2018
# 31830          Highett      4    t  1.480000e+06      S  Charlton   3/03/2018
# 20257       Thomastown      3    h  1.050173e+06     PI       Ray   3/09/2017
# 27922            Lalor      5    h  5.910000e+05      S       HAR  18/11/2017
# 10889       Yarraville      4    h  1.050173e+06     SP   Village   8/10/2016
# 31507  Blackburn North      3    h  1.050173e+06     SP    Philip   3/03/2018
#
#        Bedroom2  Bathroom  Car  Landsize  YearBuilt             Regionname
# ...

# %% [markdown]
# ## Printing information about the rows

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26129 entries, 0 to 34856
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Suburb      26129 non-null  object
#  1   Rooms       26129 non-null  int64
#  2   Type        26129 non-null  object
#  3   Price       26129 non-null  float64
#  4   Method      26129 non-null  object
#  5   SellerG     26129 non-null  object
#  6   Date        26129 non-null  object
#  7   Bedroom2    26129 non-null  float64
#  8   Bathroom    26129 non-null  float64
#  9   Car         26129 non-null  float64
#  10  Landsize    26129 non-null  float64
#  11  YearBuilt   26129 non-null  float64
#  12  Regionname  26129 non-null  object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Printing correlation of items

# %%
d.corr()
# Out:
#               Rooms     Price  Bedroom2  Bathroom       Car  Landsize  \
# Rooms      1.000000  0.387438  0.947214  0.612846  0.393878  0.034430
# Price      0.387438  1.000000  0.370407  0.367132  0.174743  0.030474
# Bedroom2   0.947214  0.370407  1.000000  0.615408  0.388491  0.034209
# Bathroom   0.612846  0.367132  0.615408  1.000000  0.307518  0.034249
# Car        0.393878  0.174743  0.388491  0.307518  1.000000  0.035408
# Landsize   0.034430  0.030474  0.034209  0.034249  0.035408  1.000000
# YearBuilt -0.015993 -0.223030 -0.006766  0.120705  0.099316  0.011660
#
#            YearBuilt
# Rooms      -0.015993
# Price      -0.223030
# Bedroom2   -0.006766
# Bathroom    0.120705
# Car         0.099316
# Landsize    0.011660
# YearBuilt   1.000000

# %% [markdown]
# ## Statistical Information about the data

# %%
d.describe().T
# Out:
#              count          mean            std      min       25%  \
# Rooms      26129.0  3.105515e+00       0.960728      1.0       3.0
# Price      26129.0  1.079804e+06  579331.163014  85000.0  722000.0
# Bedroom2   26129.0  3.089249e+00       0.982507      0.0       2.0
# Bathroom   26129.0  1.630832e+00       0.726410      0.0       1.0
# Car        26129.0  1.728845e+00       1.010771      0.0       1.0
# Landsize   26129.0  5.899056e+02    3141.495234      0.0     269.0
# YearBuilt  26129.0  1.967667e+03      28.287132   1196.0    1963.0
#
#                     50%        75%         max
# Rooms      3.000000e+00        4.0        16.0
# Price      1.050173e+06  1200000.0  11200000.0
# Bedroom2   3.000000e+00        4.0        30.0
# Bathroom   2.000000e+00        2.0        12.0
# Car        2.000000e+00        2.0        26.0
# Landsize   5.770000e+02      651.0    433014.0
# YearBuilt  1.970000e+03     1975.0      2106.0

# %% [markdown]
# ## Printing the number of unique values of each column

# %%
d.nunique()
# Out:
# Suburb         344
# Rooms           12
# Type             3
# Price         2598
# Method           9
# SellerG        358
# Date            78
# Bedroom2        15
# Bathroom        11
# Car             15
# Landsize      1667
# YearBuilt      158
# Regionname       8
# dtype: int64

# %%
d.head()
# Out:
#        Suburb  Rooms Type         Price Method SellerG       Date  Bedroom2  \
# 0  Abbotsford      2    h  1.050173e+06     SS  Jellis  3/09/2016       2.0
# 1  Abbotsford      2    h  1.480000e+06      S  Biggin  3/12/2016       2.0
# 2  Abbotsford      2    h  1.035000e+06      S  Biggin  4/02/2016       2.0
# 3  Abbotsford      3    u  1.050173e+06     VB  Rounds  4/02/2016       3.0
# 4  Abbotsford      3    h  1.465000e+06     SP  Biggin  4/03/2017       3.0
#
#    Bathroom  Car  Landsize  YearBuilt             Regionname
# 0       1.0  1.0     126.0     1970.0  Northern Metropolitan
# 1       1.0  1.0     202.0     1970.0  Northern Metropolitan
# 2       1.0  0.0     156.0     1900.0  Northern Metropolitan
# 3       2.0  1.0       0.0     1970.0  Northern Metropolitan
# 4       2.0  0.0     134.0     1900.0  Northern Metropolitan

# %%
d1 = d[(d['Regionname']=='Northern Metropolitan')&(d['Bedroom2']==2.0)]

# %%
d1[['Rooms','Price','Regionname']]
# Out:
#        Rooms         Price             Regionname
# 0          2  1.050173e+06  Northern Metropolitan
# 1          2  1.480000e+06  Northern Metropolitan
# 2          2  1.035000e+06  Northern Metropolitan
# 10         2  9.410000e+05  Northern Metropolitan
# 12         2  1.050173e+06  Northern Metropolitan
# ...      ...           ...                    ...
# 34579      2  1.050000e+06  Northern Metropolitan
# 34583      2  1.380000e+06  Northern Metropolitan
# 34589      2  1.050173e+06  Northern Metropolitan
# 34613      2  1.050173e+06  Northern Metropolitan
# 34662      2  1.185000e+06  Northern Metropolitan
#
# [1911 rows x 3 columns]

# %%
d.loc[(d['Regionname']=='Northern Metropolitan') & (d['Bedroom2']== 2.0)]
# Out:
#             Suburb  Rooms Type         Price Method  SellerG        Date  \
# 0       Abbotsford      2    h  1.050173e+06     SS   Jellis   3/09/2016
# 1       Abbotsford      2    h  1.480000e+06      S   Biggin   3/12/2016
# 2       Abbotsford      2    h  1.035000e+06      S   Biggin   4/02/2016
# 10      Abbotsford      2    h  9.410000e+05      S   Jellis   7/05/2016
# 12      Abbotsford      2    u  1.050173e+06     PI   Biggin   7/11/2016
# ...            ...    ...  ...           ...    ...      ...         ...
# 34579    Northcote      2    h  1.050000e+06     PI  McGrath  24/02/2018
# 34583    Northcote      2    h  1.380000e+06      S   Nelson  24/02/2018
# 34589    Northcote      2    h  1.050173e+06      S   Nelson  24/02/2018
# 34613  Pascoe Vale      2    h  1.050173e+06      S   Nelson  24/02/2018
# 34662     Richmond      2    h  1.185000e+06      S   Biggin  24/02/2018
#
#        Bedroom2  Bathroom  Car  Landsize  YearBuilt             Regionname
# ...

# %%
d[['Price','Regionname','Bedroom2']][(d['Regionname']=='Northern Metropolitan') & (d['Bedroom2']== 2.0)]
# Out:
#               Price             Regionname  Bedroom2
# 0      1.050173e+06  Northern Metropolitan       2.0
# 1      1.480000e+06  Northern Metropolitan       2.0
# 2      1.035000e+06  Northern Metropolitan       2.0
# 10     9.410000e+05  Northern Metropolitan       2.0
# 12     1.050173e+06  Northern Metropolitan       2.0
# ...             ...                    ...       ...
# 34579  1.050000e+06  Northern Metropolitan       2.0
# 34583  1.380000e+06  Northern Metropolitan       2.0
# 34589  1.050173e+06  Northern Metropolitan       2.0
# 34613  1.050173e+06  Northern Metropolitan       2.0
# 34662  1.185000e+06  Northern Metropolitan       2.0
#
# [1911 rows x 3 columns]

# %%
d
# Out:
#            Suburb  Rooms Type         Price Method  SellerG        Date  \
# 0      Abbotsford      2    h  1.050173e+06     SS   Jellis   3/09/2016
# 1      Abbotsford      2    h  1.480000e+06      S   Biggin   3/12/2016
# 2      Abbotsford      2    h  1.035000e+06      S   Biggin   4/02/2016
# 3      Abbotsford      3    u  1.050173e+06     VB   Rounds   4/02/2016
# 4      Abbotsford      3    h  1.465000e+06     SP   Biggin   4/03/2017
# ...           ...    ...  ...           ...    ...      ...         ...
# 34850     Wollert      3    h  1.050173e+06     SP       LJ  24/02/2018
# 34852  Yarraville      4    h  1.480000e+06     PI      Jas  24/02/2018
# 34853  Yarraville      2    h  8.880000e+05     SP  Sweeney  24/02/2018
# 34854  Yarraville      2    t  7.050000e+05      S      Jas  24/02/2018
# 34856  Yarraville      2    h  1.020000e+06     PI       RW  24/02/2018
#
#        Bedroom2  Bathroom  Car  Landsize  YearBuilt             Regionname
# ...

# %%
d1=d.groupby(['Method'])[[(d['Rooms']== 2)]]

# %%
d2 = d.groupby('Method')
d2[['Rooms','Price','Regionname']]

# %%
group = d.groupby("Method", axis=0)

# %%
d
# Out:
#            Suburb  Rooms Type         Price Method  SellerG        Date  \
# 0      Abbotsford      2    h  1.050173e+06     SS   Jellis   3/09/2016
# 1      Abbotsford      2    h  1.480000e+06      S   Biggin   3/12/2016
# 2      Abbotsford      2    h  1.035000e+06      S   Biggin   4/02/2016
# 3      Abbotsford      3    u  1.050173e+06     VB   Rounds   4/02/2016
# 4      Abbotsford      3    h  1.465000e+06     SP   Biggin   4/03/2017
# ...           ...    ...  ...           ...    ...      ...         ...
# 34850     Wollert      3    h  1.050173e+06     SP       LJ  24/02/2018
# 34852  Yarraville      4    h  1.480000e+06     PI      Jas  24/02/2018
# 34853  Yarraville      2    h  8.880000e+05     SP  Sweeney  24/02/2018
# 34854  Yarraville      2    t  7.050000e+05      S      Jas  24/02/2018
# 34856  Yarraville      2    h  1.020000e+06     PI       RW  24/02/2018
#
#        Bedroom2  Bathroom  Car  Landsize  YearBuilt             Regionname
# ...

# %%
n_data=['Rooms','Bedroom2','Car']
plt.figure(figsize=(10,5))
sns.heatmap(d[n_data].corr())
plt.show()

# %%
d.head()
# Out:
#        Suburb  Rooms Type         Price Method SellerG       Date  Bedroom2  \
# 0  Abbotsford      2    h  1.050173e+06     SS  Jellis  3/09/2016       2.0
# 1  Abbotsford      2    h  1.480000e+06      S  Biggin  3/12/2016       2.0
# 2  Abbotsford      2    h  1.035000e+06      S  Biggin  4/02/2016       2.0
# 3  Abbotsford      3    u  1.050173e+06     VB  Rounds  4/02/2016       3.0
# 4  Abbotsford      3    h  1.465000e+06     SP  Biggin  4/03/2017       3.0
#
#    Bathroom  Car  Landsize  YearBuilt             Regionname
# 0       1.0  1.0     126.0     1970.0  Northern Metropolitan
# 1       1.0  1.0     202.0     1970.0  Northern Metropolitan
# 2       1.0  0.0     156.0     1900.0  Northern Metropolitan
# 3       2.0  1.0       0.0     1970.0  Northern Metropolitan
# 4       2.0  0.0     134.0     1900.0  Northern Metropolitan

# %%
d1 = d.sample(5)
d1
# Out:
#                   Suburb  Rooms Type      Price Method   SellerG        Date  \
# 26666       Moonee Ponds      3    h  1400000.0      S  McDonald   4/11/2017
# 19947           Essendon      3    h  1210000.0      S    Nelson   3/09/2017
# 20743        Pascoe Vale      1    u   436000.0      S    Nelson   9/09/2017
# 30934  Aspendale Gardens      4    h  1000000.0     PI       Ray   3/02/2018
# 13372           Oakleigh      4    h  1145000.0      S       Ray  22/04/2017
#
#        Bedroom2  Bathroom  Car    Landsize  YearBuilt  \
# 26666       3.0       1.0  1.0  388.000000     1930.0
# 19947       3.0       2.0  2.0  593.598993     1970.0
# 20743       1.0       1.0  1.0  593.598993     1970.0
# 30934       4.0       2.0  2.0  593.598993     1970.0
# 13372       4.0       2.0  2.0  538.000000     1970.0
#
#                        Regionname
# 26666        Western Metropolitan
# 19947        Western Metropolitan
# 20743       Northern Metropolitan
# 30934  South-Eastern Metropolitan
# ...

# %%
plt.bar(d1['Regionname'],d1['Rooms'],color="red")
plt.title('Regionname Vs Rooms',fontsize=15,color='blue')
plt.xlabel('Regionname',fontsize=30)
plt.xlabel('Rooms',fontsize=15)
plt.grid(True)
plt.show()

# %%
d
# Out:
#            Suburb  Rooms Type         Price Method  SellerG        Date  \
# 0      Abbotsford      2    h  1.050173e+06     SS   Jellis   3/09/2016
# 1      Abbotsford      2    h  1.480000e+06      S   Biggin   3/12/2016
# 2      Abbotsford      2    h  1.035000e+06      S   Biggin   4/02/2016
# 3      Abbotsford      3    u  1.050173e+06     VB   Rounds   4/02/2016
# 4      Abbotsford      3    h  1.465000e+06     SP   Biggin   4/03/2017
# ...           ...    ...  ...           ...    ...      ...         ...
# 34850     Wollert      3    h  1.050173e+06     SP       LJ  24/02/2018
# 34852  Yarraville      4    h  1.480000e+06     PI      Jas  24/02/2018
# 34853  Yarraville      2    h  8.880000e+05     SP  Sweeney  24/02/2018
# 34854  Yarraville      2    t  7.050000e+05      S      Jas  24/02/2018
# 34856  Yarraville      2    h  1.020000e+06     PI       RW  24/02/2018
#
#        Bedroom2  Bathroom  Car  Landsize  YearBuilt             Regionname
# ...

# %%
d = pd.get_dummies(d,drop_first=True)

# %%
x = d.drop(['Price'],axis=1)
x
# Out:
#        Rooms  Bedroom2  Bathroom  Car  Landsize  YearBuilt  Suburb_Aberfeldie  \
# 0          2       2.0       1.0  1.0     126.0     1970.0                  0
# 1          2       2.0       1.0  1.0     202.0     1970.0                  0
# 2          2       2.0       1.0  0.0     156.0     1900.0                  0
# 3          3       3.0       2.0  1.0       0.0     1970.0                  0
# 4          3       3.0       2.0  0.0     134.0     1900.0                  0
# ...      ...       ...       ...  ...       ...        ...                ...
# 34850      3       3.0       2.0  2.0     268.0     2016.0                  0
# 34852      4       4.0       1.0  3.0     593.0     1970.0                  0
# 34853      2       2.0       2.0  1.0      98.0     2018.0                  0
# 34854      2       2.0       1.0  2.0     220.0     2000.0                  0
# 34856      2       2.0       1.0  0.0     250.0     1930.0                  0
#
# ...

# %%
y = d.Price
y
# Out:
# 0        1.050173e+06
# 1        1.480000e+06
# 2        1.035000e+06
# 3        1.050173e+06
# 4        1.465000e+06
#              ...
# 34850    1.050173e+06
# 34852    1.480000e+06
# 34853    8.880000e+05
# 34854    7.050000e+05
# 34856    1.020000e+06
# Name: Price, Length: 26129, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (19596, 800)
# (6533, 800)
# (19596,)
# (6533,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.45945300309651604

# %%
model.score(x_train,y_train)
# Out:
# 0.5172564085605411

# %%
from sklearn.linear_model import Lasso

# %%
lasso_model = Lasso(alpha=50,max_iter=100,tol=0.1)

# %%
lasso_model.fit(x_train,y_train)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_model.score(x_test,y_test)
# Out:
# 0.46380753697860266

# %%
lasso_model.score(x_train,y_train)
# Out:
# 0.5110283452010391

# %%
from sklearn.linear_model import Ridge

# %%
r_model = Ridge(alpha=50,max_iter=100,tol=0.1,solver='saga')

# %%
r_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=50, max_iter=100, solver='saga', tol=0.1)

# %%
r_model.score(x_test,y_test)
# Out:
# -0.001294127139996215

# %%
r_model.score(x_train,y_train)
# Out:
# 0.4851682186990597

# %%
solver{‘auto’, ‘svd’, ‘cholesky’, ‘lsqr’, ‘sparse_cg’, ‘sag’, ‘saga’, ‘lbfgs’},

# %%
rm=Ridge(alpha=50,
    max_iter=100,
    tol=0.1,
    {solver:['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']
})
