# %%
def call():
    
    rooms_status = {}   
    staff_info={}
    class hotel:
        global rooms_status 
        def hotelinfo(self):
                print("----------THE Garden Hotel-----")
                f = open("roominfo.txt", "r")
                print(f.readlines())
        
        def roominfo(self):
        
                print("         ------ HOTEL ROOMS INFO ------")
                print("")
                print("STANDARD NON-AC")
                print("---------------------------------------------------------------")
                print("Room amenities include: 1 Double Bed, Television, Telephone,")
                print("Double-Door Cupboard, 1 Coffee table with 2 sofa, Balcony and")
                print("an attached washroom with hot/cold water.\n")
                print("STANDARD NON-AC")
                print("---------------------------------------------------------------")
                print("Room amenities include: 1 Double Bed, Television, Telephone,")
                print("Double-Door Cupboard, 1 Coffee table with 2 sofa, Balcony and")
                print("an attached washroom with hot/cold water + Window/Split AC.\n")
                print("3-Bed NON-AC")
                print("---------------------------------------------------------------")
                print("Room amenities include: 1 Double Bed + 1 Single Bed, Television,")
                print("Telephone, a Triple-Door Cupboard, 1 Coffee table with 2 sofa, 1")
                print("Side table, Balcony with an Accent table with 2 Chair and an")
                print("attached washroom with hot/cold water.\n")
                print("3-Bed AC")
                print("---------------------------------------------------------------")
                print("Room amenities include: 1 Double Bed + 1 Single Bed, Television,")
                print("Telephone, a Triple-Door Cupboard, 1 Coffee table with 2 sofa, ")
                print("1 Side table, Balcony with an Accent table with 2 Chair and an")
                print("attached washroom with hot/cold water + Window/Split AC.\n\n")
                print()
    
        def displayroom(self):
                rooms_status = {
                      "Room1-std-AC": "Available",
                      "Room2-std-AC": "Booked",
                      "Room3-std-NonAC": "Available",
                      "Room4-std-AC": "Available",
                      "Room5-std-AC": "Available",
                      "Room6-std-AC": "Booked",
                      "Room7-3BD-NonAC": "Available",
                      "Room8-3BD-AC": "Available",
                      "Room9-3BD-AC": "Available",
                      "Room10-3BD-NonAC": "Booked",
                      "Room11-3BD-AC": "Available",
                      "Room12-3BD-NonAC": "Available",
                       }
                print(rooms_status)
                
        def staff_details(self):
                staff_info = {
                    "Ashok" : "Manager",
                    "Karthika":"Manager",
                    "Ramesh" : "Room boy",
                    "Satheesh":"Room boy",
                    "Suresh": "Cook",
                    "Appu" :"Cleaning",
                    "Parvathy": "Customer service",
                    "Daisy": "customer service",
                    }
                
                print('List of Employees:\n')
                print("------------------")

                for name, des in staff_info.items():
                        print(name, ":", des)

            
        def bookhotel(self,str):
                rooms_status = {
                      "Room1": "Available",
                      "Room2": "Booked",
                      "Room3": "Available",
                      "Room4": "Available",
                      "Room5": "Available",
                      "Room6": "Booked",
                      "Room7": "Available",
                      "Room8": "Available",
                      "Room9": "Available",
                      "Room10": "Booked",
                      "Room11": "Available",
                      "Room12": "Available",
                       }
                if rooms_status[str] == "Available":
                    rooms_status[str] = "Booked"
                    print("Room"+str+"booked successfully")
                elif rooms_status[str] == "Booked":
                    print("Already booked")
                else:
                    print("Invalid entry")
                print(rooms_status)   
                 
                
        def cancelbooking(self,str):
                rooms_status = {
                      "Room1": "Booked",
                      "Room2": "Booked",
                      "Room3": "Available",
                      "Room4": "Available",
                      "Room5": "Available",
                      "Room6": "Booked",
                      "Room7": "Available",
                      "Room8": "Available",
                      "Room9": "Available",
                      "Room10": "Booked",
                      "Room11": "Available",
                      "Room12": "Available",
                       }
                if rooms_status[str] == "Booked":
                    rooms_status[str] = "Available"
                    print(str+" cancelled successfully")
                elif rooms_status[str] == "Available":
                    print("This room is not booked")
                else:
                    print("Invalid entry")
                    
                
        
    h = hotel()
    done=False 
    while done==False:
        
            print(""" *************The garden hotel****************
              1. Display hotel details
              2. Room details
              3. Display room
              4. Book/Cancel room
              5. staff details
              6. Exit
          """)
 #       try:
            choice=int(input("Enter Choice:"))
            print(choice)
            if choice == 1:
                h.hotelinfo()
            elif choice == 2:
                h.roominfo()
            elif choice == 3:
                h.displayroom()       
            elif choice == 4:
                while True:
                    print(""" 
                          1. Book a room
                          2. Cancel Booking
                          3. Exit
                          """)
                    choice2 = int(input("Enter your choice"))
                    print(choice2)
                    if choice2 == 1:
                        room_no = input("Enter Room number to book")
                        h.bookhotel(room_no)
                    elif choice2 == 2:
                        room_no = input("Enter Room number to cancel")
                        h.cancelbooking(room_no)
                    elif choice2 == 3:
                        break
                        print("Hi")
                       # print(choice2)
                            
                    """elif choice2 == 3:
                        print("show booked")
                      #  h.displaybooked()       
                    elif choice2 == 4:   
                        print("Show available")
                       # h.available() 
                    elif choice2 == 5:
                        print("Hi")
                       # print(choice2)
                        break """
                
            elif choice == 5:
                h.staff_details()
                        
            elif choice == 6:
                break
                
            else:
                print("Please enter proper choice.")
        
     #   except:
            print("Please enter proper choice.")

        
call()
# Out:
#  *************The garden hotel****************
#               1. Display hotel details
#               2. Room details
#               3. Display room
#               4. Book/Cancel room
#               5. staff details
#               6. Exit
#
# Enter Choice:1
# 1
# ----------THE Garden Hotel-----
# ...
